# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\elias\Programs\anaconda3\envs\siisa\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\elias\Programs\anaconda3\envs\siisa\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\elias\Programs\anaconda3\envs\siisa\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\elias\Programs\anaconda3\envs\siisa\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# ...

# %%
df=pd.read_csv('ej.cvs')

# %%
df.head()
# Out:
#    executionId executionDate executionDateTime  policyId  policyVersion  \
# 0      2016143    20/05/2019             00:01         1            213
# 1      2016145    20/05/2019             00:04         1            213
# 2      2016147    20/05/2019             00:05         1            213
# 3      2016149    20/05/2019             00:07         1            213
# 4      2016150    20/05/2019             00:09         1            213
#
#                                       decisionResult  antiguedad_laboral  \
# 0  Rechaza por info SIISA: Tiene al menos un cheq...                   0
# 1                    Rechaza: ingreso_F insuficiente                   0
# 2  Rechaza por info NOSIS: Tiene al menos una Sit...                   0
# 3                                    pide info extra                   0
# 4                    Rechaza: ingreso_F insuficiente                   0
#
#       ApellidoNombre Empleador  gastos_extracto  ...  \
# ...

# %%
siisa_scorePoblacion
