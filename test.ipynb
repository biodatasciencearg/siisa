# %%
# importo las librerias que voy a utilizar.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importo el/los dataset/s que se discuten en la seccion de "descripcion del dataset"
df = pd.read_csv("Client_127_Policy_15_20190515_20190528.cvs.csv", low_memory=False)

# %%
df.head()
# Out:
#    executionId executionDate executionDateTime  policyId  policyVersion  \
# 0      1998473    15/05/2019             09:22        15             19
# 1      1998503    15/05/2019             09:28        15             19
# 2      1998507    15/05/2019             09:28        15             19
# 3      1998512    15/05/2019             09:30        15             19
# 4      1998516    15/05/2019             09:31        15             19
#
#                                       decisionResult  \
# 0                       OK|44000|Codigo rol:31906564
# 1                       OK|31000|Codigo rol:31906697
# 2                       OK|31000|Codigo rol:31906713
# 3  RECHAZA|Score SIISA (481) entre 400 y 799  y S...
# 4         RECHAZA|Rechaza por Score SIISA <= 400 (4)
#
#                       apellidoNombre cartasur_actividadLaboral  \
# 0              MORALES YANINA TERESA                   Privada
# 1            GONZALEZ   MICOL ARIANA                   Privada
# ...

# %%
df_variables_select = df.filter(regex=r'(siisa_apellido)')

# %%
df_variables_select = df_variables_select.dropna(axis=1, how='all')

# %%
df_variables_select
# Out:
#      pol1_siisa_apellidoNombre           pol13_siisa_apellidoNombre  \
# 0                          NaN                                  NaN
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                          NaN                                  NaN
# 5                          NaN                                  NaN
# 6                          NaN                                  NaN
# 7                          NaN                                  NaN
# 8                          NaN                                  NaN
# 9                          NaN                ORGNERO EVELYN NOELIA
# 10                         NaN                                  NaN
# 11                         NaN                                  NaN
# 12                         NaN                                  NaN
# ...

# %%
for i in df.columns:

    print(i)
# Out:
# executionId
# executionDate
# executionDateTime
# policyId
# policyVersion
# decisionResult
# apellidoNombre
# cartasur_actividadLaboral
# cartasur_antLaboralGral
# cartasur_canal
# cartasur_cartera
# cartasur_diasAtraso
# cartasur_diasCancelacion
# cartasur_edad
# cartasur_fNac
# cartasur_ingresos
# cartasur_juicioCancelado
# cartasur_limiteCompra
# cartasur_maxSitTar
# cartasur_metal
# cartasur_montoSolicitado
# cartasur_nroTramite
# cartasur_saldo
# cartasur_sucursal
# cuil
# nroDoc
# sexo
# pol1_callResult
# pol13_callResult
# pol16_callResult
# pol4_callResult
# pol5_callResult
# pol6_callResult
# pol7_callResult
# pol8_callResult
# callErrorMessage
# callOK
# Grupo_sucursal
# pol1_apellidoNombre
# pol1_cartasur_actividadLaboral
# pol1_cartasur_antLaboralGral
# pol1_cartasur_canal
# pol1_cartasur_cartera
# pol1_cartasur_diasAtraso
# pol1_cartasur_diasCancelacion
# pol1_cartasur_edad
# pol1_cartasur_fNac
# pol1_cartasur_ingresos
# pol1_cartasur_juicioCancelado
# ...

# %%
import json
# reading the JSON data using json.load()
df = pd.read_json(r'Results.json', orient='columns')
#with open(r'Results.json') as data_file: 
#    data = json.load(data_file)
#import pandas as pd
#from pandas.io.json import json_normalize
#json_normalize(df)

# %%
df
# Out:
#      executionId                         varName  \
# 0        1998473                  apellidoNombre
# 1        1998473                callErrorMessage
# 2        1998473                          callOK
# 3        1998473       cartasur_actividadLaboral
# 4        1998473         cartasur_antLaboralGral
# 5        1998473                  cartasur_canal
# 6        1998473                cartasur_cartera
# 7        1998473             cartasur_diasAtraso
# 8        1998473        cartasur_diasCancelacion
# 9        1998473                   cartasur_edad
# 10       1998473                   cartasur_fNac
# 11       1998473               cartasur_ingresos
# 12       1998473        cartasur_juicioCancelado
# 13       1998473           cartasur_limiteCompra
# 14       1998473              cartasur_maxSitTar
# 15       1998473                  cartasur_metal
# 16       1998473        cartasur_montoSolicitado
# 17       1998473             cartasur_nroTramite
# ...

# %%
# Create URL to JSON file (alternatively this can be a filepath)
#url = 'https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json'

# Load the first sheet of the JSON file into a data frame
df = pd.read_json('data.json', orient='columns')

# View the first ten rows
df.head(10)
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 10        5 2015-01-01 00:00:10         0
# 11        5 2015-01-01 00:00:11         0
# 12        8 2015-01-01 00:00:12         0
# 13        9 2015-01-01 00:00:13         0
# 14        8 2015-01-01 00:00:14         0
# 15        8 2015-01-01 00:00:15         0
# 16        2 2015-01-01 00:00:16         0
# 17        1 2015-01-01 00:00:17         0
